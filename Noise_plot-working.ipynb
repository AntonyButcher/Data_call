# %%
from obspy.fdsn import Client
import obspy
from obspy import UTCDateTime

from numpy import *
import numpy as np 
import matplotlib.pyplot as plt
import scipy

# %matplotlib inline

client = Client()

# %%
t = UTCDateTime("2010-02-15T00:00:00.000")
st = client.get_waveforms("GB", "HTL", "*", "BHZ", t, t + 3600*48, attach_response=True)
print st
# Out:
# 1 Trace(s) in Stream:
# GB.HTL..BHZ | 2010-02-15T00:00:00.015000Z - 2010-02-16T23:59:59.995000Z | 50.0 Hz, 8640000 samples

# %%
st_inst=st.copy() 
st_inst.merge()
st_inst.remove_response(output="VEL") 
st_inst.filter('highpass', freq=0.02, corners=2, zerophase=True)
st_inst.taper(max_percentage=0.01, type='cosine')

print(st_inst)
st_inst.plot()
# Out:
# 1 Trace(s) in Stream:
# GB.HTL..BHZ | 2010-02-15T00:00:00.015000Z - 2010-02-16T23:59:59.995000Z | 50.0 Hz, 8640000 samples

# %%
t1=st_inst[0].stats.starttime
t2=st_inst[0].stats.endtime
samp_rate=st_inst[0].stats.sampling_rate  

fin_len=len(st_inst[0])
print len(st_inst[0])
print samp_rate
# Out:
# 8640000
# 50.0

# %%
data=np.array((0))
time=np.array((0))
freq=np.array((0))
print time.shape
print st_inst[0]
# Out:
# ()
# GB.HTL..BHZ | 2010-02-15T00:00:00.015000Z - 2010-02-16T23:59:59.995000Z | 50.0 Hz, 8640000 samples

# %%
t=t1

while t < t2:
    cut=st_inst[0].slice(t,t+1200)
    tmid=t+600
    t=t+1200
    length = len(cut)-1
    print length

    time_temp=np.zeros(shape=(length,1))
        
    for a in range(0,length):
        time_temp[a]=[tmid.timestamp]

    time=vstack((time,time_temp))

    
    cut_data=cut.data
    cut_spec=np.fft.fft(cut_data,n=length)
    
    data_temp=np.zeros(shape=(length,1),dtype=np.complex)
        
    for b in range(0,length):
        data_temp[b]=cut_spec[b]
    
    data=vstack((data,data_temp))
       
    freq_temp = np.fft.fftfreq(length, d=1./samp_rate)
    
    freq_temp2=np.zeros(shape=(length,1))
        
    for c in range(0,length):
        freq_temp2[c]=freq_temp[c]   
    
    
    freq=vstack((freq,freq_temp2))
    
    
        
    plt.plot(abs(freq_temp),abs(cut_spec))
    plt.xlim([-1,25])
    plt.ylim([0,0.00001])
    plt.show()

    
print time
print len(time)
print data
print len(data)
print freq
print len(freq)
    
time=np.delete(time,0,0)
data=np.delete(data,0,0)
freq=np.delete(freq,0,0)

print time
print len(time)
print data
print len(data)
print freq
print len(freq)
# Out:
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 60000
# 59999
# [[  0.00000000e+00]
#  [  1.26619260e+09]
#  [  1.26619260e+09]
#  ...,
#  [  1.26636420e+09]
#  [  1.26636420e+09]
#  [  1.26636420e+09]]
# 8640000
# [[  0.00000000e+00 +0.00000000e+00j]
#  [  1.01767232e-05 +0.00000000e+00j]
#  [  1.01770651e-05 -3.48586562e-08j]
#  ...,
#  [  4.95870993e-06 +2.24147942e-07j]
#  [  4.93703728e-06 +1.42028417e-07j]
#  [  4.94212239e-06 +7.80241936e-08j]]
# 8640000
# [[ 0.        ]
#  [ 0.        ]
#  [ 0.00083333]
#  ...,
#  [-0.00250004]
#  [-0.00166669]
#  [-0.00083335]]
# 8640000
# [[  1.26619260e+09]
#  [  1.26619260e+09]
#  [  1.26619260e+09]
#  ...,
#  [  1.26636420e+09]
#  [  1.26636420e+09]
#  [  1.26636420e+09]]
# 8639999
# [[  1.01767232e-05 +0.00000000e+00j]
#  [  1.01770651e-05 -3.48586562e-08j]
#  [  1.01773019e-05 -6.72353217e-08j]
#  ...,
#  [  4.95870993e-06 +2.24147942e-07j]
#  [  4.93703728e-06 +1.42028417e-07j]
#  [  4.94212239e-06 +7.80241936e-08j]]
# 8639999
# [[ 0.        ]
#  [ 0.00083333]
#  [ 0.00166667]
#  ...,
#  [-0.00250004]
#  [-0.00166669]
#  [-0.00083335]]
# 8639999

# %%
print time
print len(time)
print data
print len(data)
print freq
print len(freq)
# Out:
# [[  1.26619260e+09]
#  [  1.26619260e+09]
#  [  1.26619260e+09]
#  ...,
#  [  1.26636420e+09]
#  [  1.26636420e+09]
#  [  1.26636420e+09]]
# 8639999
# [[  1.01767232e-05 +0.00000000e+00j]
#  [  1.01770651e-05 -3.48586562e-08j]
#  [  1.01773019e-05 -6.72353217e-08j]
#  ...,
#  [  4.95870993e-06 +2.24147942e-07j]
#  [  4.93703728e-06 +1.42028417e-07j]
#  [  4.94212239e-06 +7.80241936e-08j]]
# 8639999
# [[ 0.        ]
#  [ 0.00083333]
#  [ 0.00166667]
#  ...,
#  [-0.00250004]
#  [-0.00166669]
#  [-0.00083335]]
# 8639999

# %%
plt.plot(time, freq,'rx')

plt.show()

# %%
x=np.linspace(0, 8639999, num=8639999)
print len(x)
# Out:
# 8639999

# %%
plt.plot(abs(freq[70000:719999]), abs(data[70000:719999]))
plt.show()
plt.plot(time, abs(data))
plt.ylim(0,0.0001)
plt.show()
# Out:
# /Users/ab14785/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter: Allocated too many blocks
#   FormatterWarning,

# %%
x=np.array(())
y=np.array(())
z=np.array(())


x = np.append(x,time)
y = np.append(y,abs(freq))
z = np.append(z,abs(data))

# %%
from scipy import signal

z_flt=scipy.signal.medfilt(z,21)

# %%
print x.shape
print y.shape
print z.shape
# Out:
# (8639999,)
# (8639999,)
# (8639999,)

# %%
plt.plot(x,y, 'rx') # Plot irregular data grid
plt.title("Data locations")

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as ml

ndata = len(data)
ny, nx = 0.5, 1000
xmin, xmax = x.min(), x.max()
ymin, ymax = y.min(), y.max()
# x = np.linspace(1, 10, ndata)
# y = np.linspace(1, 10, ndata)

xi, yi = np.mgrid[x.min():x.max():nx, ymin:ymax:ny]

#xi = np.linspace(xmin, xmax, nx)
#yi = np.linspace(ymin, ymax, ny)

print ymax

print xi.size
print yi.size

plt.plot(xi,yi, 'rx')
# Out:
# 25.0
# 8600
# 8600
# [<matplotlib.lines.Line2D at 0x114e77350>,
#  <matplotlib.lines.Line2D at 0x114e77190>,
#  <matplotlib.lines.Line2D at 0x114e77b10>,
#  <matplotlib.lines.Line2D at 0x114e77650>,
#  <matplotlib.lines.Line2D at 0x114e77ad0>,
#  <matplotlib.lines.Line2D at 0x10b5c8090>,
#  <matplotlib.lines.Line2D at 0x10b5c8210>,
#  <matplotlib.lines.Line2D at 0x10b5c8390>,
#  <matplotlib.lines.Line2D at 0x10b5c8510>,
#  <matplotlib.lines.Line2D at 0x10b5c8690>,
#  <matplotlib.lines.Line2D at 0x10b5c8810>,
#  <matplotlib.lines.Line2D at 0x10b5c8990>,
#  <matplotlib.lines.Line2D at 0x10b5c8f50>,
#  <matplotlib.lines.Line2D at 0x10b5c8e10>,
#  <matplotlib.lines.Line2D at 0x107fec9d0>,
#  <matplotlib.lines.Line2D at 0x107fec150>,
#  <matplotlib.lines.Line2D at 0x107fece90>,
#  <matplotlib.lines.Line2D at 0x107fec650>,
#  <matplotlib.lines.Line2D at 0x107fec850>,
#  <matplotlib.lines.Line2D at 0x107fec250>,
#  <matplotlib.lines.Line2D at 0x107fec510>,
#  <matplotlib.lines.Line2D at 0x107feced0>,
#  <matplotlib.lines.Line2D at 0x107fecc90>,
#  <matplotlib.lines.Line2D at 0x107fecb90>,
#  <matplotlib.lines.Line2D at 0x10ff2f950>,
#  <matplotlib.lines.Line2D at 0x10ff2f810>,
#  <matplotlib.lines.Line2D at 0x10ff2f110>,
#  <matplotlib.lines.Line2D at 0x10ff2fcd0>,
#  <matplotlib.lines.Line2D at 0x10ff2f210>,
#  <matplotlib.lines.Line2D at 0x10ff2ff90>,
#  <matplotlib.lines.Line2D at 0x10ff2ffd0>,
#  <matplotlib.lines.Line2D at 0x10ff2f290>,
#  <matplotlib.lines.Line2D at 0x10ff2f5d0>,
#  <matplotlib.lines.Line2D at 0x10ff2f090>,
#  <matplotlib.lines.Line2D at 0x1326b5150>,
#  <matplotlib.lines.Line2D at 0x1328b7f50>,
#  <matplotlib.lines.Line2D at 0x1328b7e90>,
#  <matplotlib.lines.Line2D at 0x1328b7050>,
#  <matplotlib.lines.Line2D at 0x1328b7450>,
#  <matplotlib.lines.Line2D at 0x1328b7b90>,
#  <matplotlib.lines.Line2D at 0x1328b73d0>,
#  <matplotlib.lines.Line2D at 0x1328b7550>,
#  <matplotlib.lines.Line2D at 0x1328b7290>,
#  <matplotlib.lines.Line2D at 0x1328b7a50>,
#  <matplotlib.lines.Line2D at 0x1328b7350>,
#  <matplotlib.lines.Line2D at 0x10ea1c710>,
#  <matplotlib.lines.Line2D at 0x10ea1c510>,
#  <matplotlib.lines.Line2D at 0x10ea1c490>,
#  <matplotlib.lines.Line2D at 0x10ea1c090>,
#  <matplotlib.lines.Line2D at 0x10ea1cd50>]

# %%
points = x,y
values = z
values2 = z_flt

# %%
from scipy.interpolate import griddata

# %%
grid_z0 = griddata(points, values, (xi, yi), method='nearest') 
grid_z0_flt = griddata(points, values2, (xi, yi), method='nearest')

# %%
fig = plt.figure()
plt.contourf(xi, yi, grid_z0,1000) 
#plt.ylim(5, 10)
plt.clim(0,0.000005)
#plt.axis('off') # Don't want axis on jpeg
#plt.savefig('data.jpg', dpi=100, bbox_inches='tight', pad_inches=0)

fig = plt.figure()
plt.contourf(xi, yi, grid_z0_flt,1000) 
plt.contour3D(xi, yi, grid_z0_flt,1000)
#plt.ylim(5, 10)
plt.clim(0,0.00001)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-a6662a1d734f> in <module>()
#       8 fig = plt.figure()
#       9 plt.contourf(xi, yi, grid_z0_flt,1000)
# ---> 10 plt.contour3D(xi, yi, grid_z0_flt,1000)
#      11 #plt.ylim(5, 10)
#      12 plt.clim(0,0.00001)
#
# AttributeError: 'module' object has no attribute 'contour3D'

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.contourf3D(xi, yi, grid_z0_flt,1000)
plt.ylim(5,25)
#ax.plot_trisurf(xi, yi, grid_z0_flt, linewidth=0.2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as ml

np.random.seed(8)
ndata = 10
ny, nx = 100, 200
xmin, xmax = 1, 10
ymin, ymax = 1, 10
x = np.linspace(1, 10, ndata)
y = np.linspace(1, 10, ndata)
z = np.random.random(ndata)
x = np.r_[x,xmin,xmax]
y = np.r_[y,ymax,ymin]
z = np.r_[z,z[0],z[-1]]
xi = np.linspace(xmin, xmax, nx)
yi = np.linspace(ymin, ymax, ny)
zi = ml.griddata(x, y, z, xi, yi)

plt.contour(xi, yi, zi, 15, linewidths = 0.5, colors = 'k')
plt.pcolormesh(xi, yi, zi, cmap = plt.get_cmap('rainbow'))

plt.colorbar() 
plt.scatter(x, y, marker = 'o', c = 'b', s = 10, zorder = 10)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-199-077696e8b36d> in <module>()
#      16 xi = np.linspace(xmin, xmax, nx)
#      17 yi = np.linspace(ymin, ymax, ny)
# ---> 18 zi = ml.griddata(x, y, z, xi, yi)
#      19
#      20 plt.contour(xi, yi, zi, 15, linewidths = 0.5, colors = 'k')
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/mlab.pyc in griddata(x, y, z, xi, yi, interp)
#    3441             from mpl_toolkits.natgrid import _natgrid
#    3442         except ImportError:
# -> 3443             raise RuntimeError("To use interp='nn' (Natural Neighbor "
#    3444                 "interpolation) in griddata, natgrid must be installed.  "
#    3445                 "Either install it from http://sourceforge.net/projects/"
#
# RuntimeError: To use interp='nn' (Natural Neighbor interpolation) in griddata, natgrid must be installed.  Either install it from http://sourceforge.net/projects/matplotlib/files/matplotlib-toolkits, or use interp='linear' instead.

# %%
plt.scatter(x,y,c=g)

# %%
all_data=np.concatenate((time,abs(freq),abs(data)), axis=1)
print all_data
# Out:
# [[  1.26619260e+09   0.00000000e+00   7.07948352e-06]
#  [  1.26619260e+09   8.33333333e-04   8.42986322e-06]
#  [  1.26619260e+09   1.66666667e-03   1.16013548e-05]
#  ...,
#  [  1.26620580e+09   2.50004167e-03   2.92593891e-05]
#  [  1.26620580e+09   1.66669444e-03   2.94659575e-05]
#  [  1.26620580e+09   8.33347222e-04   2.93509103e-05]]

# %%
imgplot = plt.imshow(all_data)

# %%
plt.contour(all_data[:,0], all_data[:,1], all_data[:,2], 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-d3b5be799f09> in <module>()
# ----> 1 plt.contour(all_data[:,0], all_data[:,1], all_data[:,2], 50)
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2692         ax.hold(hold)
#    2693     try:
# -> 2694         ret = ax.contour(*args, **kwargs)
#    2695         draw_if_interactive()
#    2696     finally:
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in contour(self, *args, **kwargs)
#    5316             self.cla()
#    5317         kwargs['filled'] = False
# -> 5318         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5319     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    5320
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1426         are described in QuadContourSet.contour_doc.
#    1427         """
# -> 1428         ContourSet.__init__(self, ax, *args, **kwargs)
#    1429
#    1430     def _process_args(self, *args, **kwargs):
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     872         self._transform = kwargs.get('transform', None)
#     873
# --> 874         self._process_args(*args, **kwargs)
#     875         self._process_levels()
#     876
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _process_args(self, *args, **kwargs)
#    1439             self.zmax = args[0].zmax
#    1440         else:
# -> 1441             x, y, z = self._contour_args(args, kwargs)
#    1442
#    1443             _mask = ma.getmask(z)
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _contour_args(self, args, kwargs)
#    1503             args = args[1:]
#    1504         elif Nargs <= 4:
# -> 1505             x, y, z = self._check_xyz(args[:3], kwargs)
#    1506             args = args[3:]
#    1507         else:
#
# /Users/ab14785/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _check_xyz(self, args, kwargs)
#    1537
#    1538         if z.ndim != 2:
# -> 1539             raise TypeError("Input z must be a 2D array.")
#    1540         else:
#    1541             Ny, Nx = z.shape
#
# TypeError: Input z must be a 2D array.
