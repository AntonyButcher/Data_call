# %%
from obspy.fdsn import Client
from obspy import UTCDateTime
# %matplotlib inline
client = Client()
t = UTCDateTime("2010-02-27T06:45:00.000")
st = client.get_waveforms("CN", "YK*", "*", "BHE", t, t + 120 * 60)
print st 
st.plot()
# Out:
# 1 Trace(s) in Stream:
# CN.YKW3..BHE | 2010-02-27T06:45:00.000000Z - 2010-02-27T08:45:00.000000Z | 20.0 Hz, 144001 samples
